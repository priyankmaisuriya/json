# %%
df = spark.read.json('/FileStore/tables/sample2.json')
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df=spark.read.json("/FileStore/tables/demo.json")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_corrupt_record</th><th>city</th><th>type</th></tr></thead><tbody><tr><td>{</td><td>null</td><td>null</td></tr><tr><td>	"id":"1",</td><td>null</td><td>null</td></tr><tr><td>	"firstName":"rocky",</td><td>null</td><td>null</td></tr><tr><td>	"lastName":"kgf"</td><td>null</td><td>null</td></tr><tr><td>    },</td><td>null</td><td>null</td></tr><tr><td>	"address": [</td><td>null</td><td>null</td></tr><tr><td>null</td><td>bardoli</td><td>home</td></tr><tr><td>   ]</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
df=spark.read.json("/FileStore/tables/demo-1.json")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
